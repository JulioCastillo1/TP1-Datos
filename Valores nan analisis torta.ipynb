# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

train = pd.read_csv('train.csv')
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train['keyword'].isna().sum()
# Out:
# 61

# %%
train['location'].isna().sum()
# Out:
# 2533

# %%
train.shape[0]
# Out:
# 7613

# %%
plt.rcParams['figure.dpi'] = 150

info1  = pd.Series([train['keyword'].isna().sum(),train.shape[0]-train['keyword'].isna().sum()], index = ['Null value','Not null value'], name = '')
info2 = pd.Series([train['location'].isna().sum(),train.shape[0]-train['location'].isna().sum()], index = ['Null value','Not null value'], name = '')
                  
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.set_title('Keyword Field')
ax2.set_title('LocationField')
#fig.tight_layout()
fig.suptitle('Nan values vs not nan values on different fields')

info1.plot(kind='pie', ax = ax1,colormap = 'Set1')

info2.plot(kind= 'pie',ax = ax2, colormap = 'Set1')
plt.subplots_adjust(wspace = 0.5)
