# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm
tqdm.pandas()

tweets = pd.read_csv('train.csv')
tweets.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
tweets = tweets.loc[~tweets['location'].isna()]
tweets.head()
# Out:
#     id keyword                       location  \
# 31  48  ablaze                     Birmingham
# 32  49  ablaze  Est. September 2012 - Bristol
# 33  50  ablaze                         AFRICA
# 34  52  ablaze               Philadelphia, PA
# 35  53  ablaze                     London, UK
#
#                                                  text  target
# 31  @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 32  We always try to bring the heavy. #metal #RT h...       0
# 33  #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 34                 Crying out for more! Set me ablaze       0
# 35  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0

# %%
def seriesOfLocations(series):
    lista = []
    for text in series:
        toadd = geolocator.geocode(text)
        if (toadd == None):
            lista.append(0)
        else:
            lista.append(toadd)
    return pd.Series(lista)

geolocator = Nominatim(user_agent = "TP1 1C2020 7506 FIUBA")

geocode = RateLimiter(geolocator.geocode, min_delay_seconds = 0.5)

# %%
tweets['geolocation'] = tweets['location'].apply(geocode)
tweets.head()
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Australia',), **{}).
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/urllib/request.py", line 1325, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "/usr/lib/python3.6/http/client.py", line 1264, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/usr/lib/python3.6/http/client.py", line 1310, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/usr/lib/python3.6/http/client.py", line 1259, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/usr/lib/python3.6/http/client.py", line 1038, in _send_output
#     self.send(msg)
#   File "/usr/lib/python3.6/http/client.py", line 976, in send
#     self.connect()
#   File "/usr/lib/python3.6/http/client.py", line 1425, in connect
#     server_hostname=server_hostname)
# ...

# %%
# Out:
# dtype('O')
