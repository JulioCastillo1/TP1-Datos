# %% [markdown]
# <a href="https://colab.research.google.com/github/JulioCastillo1/TP1-Datos/blob/master/Violin_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/JulioCastillo1/TP1-Datos/master/tweets_length.csv"

tweetsLengths = pd.read_csv(url)
tweetsLengths
# Out:
#       Unnamed: 0     id  ... target longitud
# 0              0      1  ...      1       69
# 1              1      4  ...      1       38
# 2              2      5  ...      1      133
# 3              3      6  ...      1       65
# 4              4      7  ...      1       88
# ...          ...    ...  ...    ...      ...
# 7608        7608  10869  ...      1       83
# 7609        7609  10870  ...      1      125
# 7610        7610  10871  ...      1       65
# 7611        7611  10872  ...      1      137
# 7612        7612  10873  ...      1       94
#
# [7613 rows x 7 columns]

# %%
data=tweetsLengths[['target','longitud']]
data
# Out:
#       target  longitud
# 0          1        69
# 1          1        38
# 2          1       133
# 3          1        65
# 4          1        88
# ...      ...       ...
# 7608       1        83
# 7609       1       125
# 7610       1        65
# 7611       1       137
# 7612       1        94
#
# [7613 rows x 2 columns]

# %%
data.target.replace([0,1],['Falso','Verdadero'],inplace=True)
data
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#          target  longitud
# 0     Verdadero        69
# 1     Verdadero        38
# 2     Verdadero       133
# 3     Verdadero        65
# 4     Verdadero        88
# ...         ...       ...
# 7608  Verdadero        83
# 7609  Verdadero       125
# 7610  Verdadero        65
# 7611  Verdadero       137
# 7612  Verdadero        94
#
# [7613 rows x 2 columns]

# %%
#plt.rc('xtick', labelsize=10)
#plt.rc('ytick', labelsize=10)
#plt.xlabel("Target", fontsize=20)
#plt.ylabel("Longitud de los tweets", fontsize=20)
#plt.figure(figsize=(30,20))
catplot=sns.catplot(x="target", y="longitud", kind="violin", inner=None, heigth=10, data=data)
plt.title("Relación entre la longitud de los tweets y la veracidad", fontsize=10)
#plt.figure(figsize=(30,20))
sns.swarmplot(x="target", y="longitud", size=2, data=data, ax=catplot.ax, hue="target")
plt.title("Relación entre la longitud de los tweets y la veracidad", fontsize=10)
#plt.figure(figsize=(30,20))
# Out:
# Text(0.5, 1.0, 'Relación entre la longitud de los tweets y la veracidad')
