# %% [markdown]
# <a href="https://colab.research.google.com/github/JulioCastillo1/TP1-Datos/blob/master/Violin_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/JulioCastillo1/TP1-Datos/master/tweets_length.csv"

tweetsLengths = pd.read_csv(url)
tweetsLengths
# Out:
#       Unnamed: 0     id  ... target longitud
# 0              0      1  ...      1       69
# 1              1      4  ...      1       38
# 2              2      5  ...      1      133
# 3              3      6  ...      1       65
# 4              4      7  ...      1       88
# ...          ...    ...  ...    ...      ...
# 7608        7608  10869  ...      1       83
# 7609        7609  10870  ...      1      125
# 7610        7610  10871  ...      1       65
# 7611        7611  10872  ...      1      137
# 7612        7612  10873  ...      1       94
#
# [7613 rows x 7 columns]

# %%
data=tweetsLengths[['target','longitud']]

# %%
plt.figure(figsize=(15,12))
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.title("Relación entre la longitud de los tweets y la veracidad", fontsize=25)
plt.xlabel("Target", fontsize=20)
plt.ylabel("Longitud de los tweets", fontsize=20)
sns.violinplot(x="target", y="longitud", data=data)

# %%
#plt.rc('xtick', labelsize=10)
#plt.rc('ytick', labelsize=10)
#plt.xlabel("Target", fontsize=20)
#plt.ylabel("Longitud de los tweets", fontsize=20)
catplot=sns.catplot(x="target", y="longitud", kind="violin", inner=None, heigth=5, data=data)
sns.swarmplot(x="target", y="longitud", size=2, data=data, ax=catplot.ax, hue="target")
plt.figure(figsize=(30,20))
#plt.title("Relación entre la longitud de los tweets y la veracidad", fontsize=25)
